# %% [markdown]
# <a href="https://colab.research.google.com/github/MarioEspinoza15/pw15162022/blob/main/06.%20RenComb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Renombrado y Combinación
#
# En este JNB se revisará el tema de Renombrado y Combinación en Pandas.

# %%
import pandas as pd
pd.set_option('max_rows', 5)
reviews = pd.read_csv("https://raw.githubusercontent.com/GTD2101-ACD-GA-AD22/Pandas-19170574/main/data/winemag-data-130k-v2.csv?token=GHSAT0AAAAAABZTG4JDC3POXLOSLTYGEGGWYZ6LK7A", index_col=0)

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...               ...                                                ...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# firstEntry                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# secondEntry                       Avidagos      87   15.0              Douro
# ...                                    ...     ...    ...                ...
# 129969                                 NaN      90   32.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# ...

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# fields region_1 region_2    taster_name taster_twitter_handle  \
# wines
# ...

# %%
canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-cf004620a004> in <module>
# ----> 1 canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
#       2 british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")
#       3
#       4 pd.concat([canadian_youtube, british_youtube])
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b5c223952364> in <module>
# ----> 1 left = canadian_youtube.set_index(['title', 'trending_date'])
#       2 right = british_youtube.set_index(['title', 'trending_date'])
#       3
#       4 left.join(right, lsuffix='_CAN', rsuffix='_UK')
#
# NameError: name 'canadian_youtube' is not defined
